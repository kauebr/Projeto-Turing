# %% [markdown]
# <a href="https://colab.research.google.com/github/kauebr/Projeto-Turing/blob/main/Teste_de_correla%C3%A7%C3%B5es_v_001.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Código Inicial — Levantamento Inicial, Visualização e Pré-Processamento dos Dados
#
# Neste bloco, realizo a visualização inicial do dataset do **Sistema de Informações sobre Mortalidade (SIM)**. Também inicio o cálculo de colunas dependentes da variável alvo.
#
# 📄 **Fonte dos dados (CSV):**
# https://s3.sa-east-1.amazonaws.com/ckan.saude.gov.br/SIM/DO23OPEN.csv
#
# 📘 **Dicionário de Dados (Data Dictionary):**
# https://diaad.s3.sa-east-1.amazonaws.com/sim/Mortalidade_Geral+-+Estrutura.pdf
#
#  **Site Base dos dados:**
# https://opendatasus.saude.gov.br/dataset/sim/

# %% [markdown]
# # Importando Bibliotecas e dados

# %%
import pandas as pd
import numpy as np

# %%
url = 'https://s3.sa-east-1.amazonaws.com/ckan.saude.gov.br/SIM/DO24OPEN.csv'
df = pd.read_csv(url, sep=';', encoding='latin1')  # usa ; como separador e latin1 para acentuação

df.head()  # mostra as primeiras linhas
# Out:
# <ipython-input-8-cd27b95bc468>:2: DtypeWarning: Columns (65) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(url, sep=';', encoding='latin1')  # usa ; como separador e latin1 para acentuação
#    contador  ORIGEM  TIPOBITO   DTOBITO  HORAOBITO  NATURAL  CODMUNNATU  \
# 0         1       1         2  19042024     2301.0    824.0    240490.0
# 1         2       1         2  18012024     1030.0    824.0    240940.0
# 2         3       1         2  22012024      700.0    824.0    241250.0
# 3         4       1         2  24032024     1220.0    824.0    241050.0
# 4         5       1         2  12012024      800.0    824.0    240320.0
#
#        DTNASC  IDADE  SEXO  ...  TPRESGINFO  TPNIVELINV  DTCADINF  MORTEPARTO  \
# 0  24121964.0    459     1  ...         NaN         NaN       NaN         NaN
# 1  29041958.0    465     2  ...         NaN         NaN       NaN         NaN
# 2  23031939.0    484     2  ...         NaN         NaN       NaN         NaN
# 3  10061944.0    479     2  ...         NaN         NaN       NaN         NaN
# 4   8031950.0    473     2  ...         NaN         NaN       NaN         NaN
#
#    DTCONCASO  ALTCAUSA  CAUSABAS_O  TPPOS  TP_ALTERA  CB_ALT
# 0        NaN       NaN        I279      N        NaN     NaN
# 1        NaN       NaN         A09      N        NaN     NaN
# 2        NaN       NaN        E112      N        NaN     NaN
# 3        NaN       NaN        G309      N        NaN     NaN
# 4        NaN       NaN        I219      N        NaN     NaN
#
# [5 rows x 86 columns]

# %%
# Exibindo o tamanho do modelo
df.shape
# Out:
# (1426346, 86)

# %%
# Caculando tamanho do nosso conjunto de dados(dataframe)
1465610 * 86
# Out:
# 126042460

# %% [markdown]
# # Análise exploratória

# %%
df['CID10']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'CID10'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-14-988ce9fc7438> in <cell line: 0>()
# ----> 1 df['CID10']
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    4100             if self.columns.nlevels > 1:
#    4101                 return self._getitem_multilevel(key)
# -> 4102             indexer = self.columns.get_loc(key)
#    4103             if is_integer(indexer):
#    4104                 indexer = [indexer]
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3810             ):
#    3811                 raise InvalidIndexError(key)
# -> 3812             raise KeyError(key) from err
#    3813         except TypeError:
#    3814             # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 'CID10'

# %%
df['CIRCOBITO'].isnull().sum()
# Out:
# np.int64(1283156)

# %%
# Total de entradas
total = len(df)
coluna = 'CIRCOBITO'

# Verificações
nulos = df[coluna].isnull().sum()
vazios = (df[coluna] == '').sum()
nan_texto = (df[coluna].astype(str).str.upper() == 'NAN').sum()

# Numéricos (exclui NaN e vazios antes de checar)
numericos = pd.to_numeric(df[coluna], errors='coerce').notna().sum()

# Percentuais
print(f"Análise da coluna {coluna} (%):")
print(f"- Valores nulos (NaN/None): {nulos / total:.2%}")
print(f"- Valores em branco (''): {vazios / total:.2%}")
print(f"- Texto 'NaN': {nan_texto / total:.2%}")
print(f"- Valores numéricos válidos: {numericos / total:.2%}")
print(f"- Temos {df.shape[0] - nulos} dados para trabalhar")
# Out:
# Análise da coluna CIRCOBITO (%):
# - Valores nulos (NaN/None): 89.96%
# - Valores em branco (''): 0.00%
# - Texto 'NaN': 89.96%
# - Valores numéricos válidos: 10.04%
# - Temos 143190 dados para trabalhar

# %%
# !pip install pysus
# Out:
# Collecting pysus
#   Downloading pysus-0.15.0-py3-none-any.whl.metadata (1.3 kB)
# Collecting Unidecode<2.0.0,>=1.3.6 (from pysus)
#   Downloading Unidecode-1.4.0-py3-none-any.whl.metadata (13 kB)
# Collecting aioftp<0.22.0,>=0.21.4 (from pysus)
#   Downloading aioftp-0.21.4-py3-none-any.whl.metadata (6.1 kB)
# Collecting bigtree<0.13.0,>=0.12.2 (from pysus)
#   Downloading bigtree-0.12.5-py3-none-any.whl.metadata (28 kB)
# Collecting cffi==1.15.1 (from pysus)
#   Downloading cffi-1.15.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.1 kB)
# Collecting dateparser<2.0.0,>=1.1.8 (from pysus)
#   Downloading dateparser-1.2.1-py3-none-any.whl.metadata (29 kB)
# Collecting dbfread==2.0.7 (from pysus)
#   Downloading dbfread-2.0.7-py2.py3-none-any.whl.metadata (3.3 kB)
# Collecting elasticsearch==7.16.2 (from elasticsearch[preprocessing]==7.16.2->pysus)
#   Downloading elasticsearch-7.16.2-py2.py3-none-any.whl.metadata (5.7 kB)
# Collecting fastparquet>=2023.10.1 (from pysus)
#   Downloading fastparquet-2024.11.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.2 kB)
# Requirement already satisfied: humanize<5.0.0,>=4.8.0 in /usr/local/lib/python3.11/dist-packages (from pysus) (4.12.3)
# Collecting loguru<0.7.0,>=0.6.0 (from pysus)
#   Downloading loguru-0.6.0-py3-none-any.whl.metadata (21 kB)
# Collecting numpy==1.26.2 (from pysus)
#   Downloading numpy-1.26.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.2/61.2 kB 4.5 MB/s eta 0:00:00
# Requirement already satisfied: pandas<3.0.0,>=2.2.2 in /usr/local/lib/python3.11/dist-packages (from pysus) (2.2.2)
# Requirement already satisfied: pyarrow>=11.0.0 in /usr/local/lib/python3.11/dist-packages (from pysus) (18.1.0)
# Collecting pycparser==2.21 (from pysus)
#   Downloading pycparser-2.21-py2.py3-none-any.whl.metadata (1.1 kB)
# Collecting pyreaddbc>=1.1.0 (from pysus)
#   Downloading pyreaddbc-1.2.0.tar.gz (57 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.7/57.7 kB 5.1 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting python-dateutil==2.8.2 (from pysus)
#   Downloading python_dateutil-2.8.2-py2.py3-none-any.whl.metadata (8.2 kB)
# Collecting tqdm==4.64.0 (from pysus)
#   Downloading tqdm-4.64.0-py2.py3-none-any.whl.metadata (57 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.3/57.3 kB 4.8 MB/s eta 0:00:00
# Requirement already satisfied: typing-extensions<5.0.0,>=4.9.0 in /usr/local/lib/python3.11/dist-packages (from pysus) (4.14.0)
# Collecting urwid<3.0.0,>=2.1.2 (from pysus)
#   Downloading urwid-2.6.16-py3-none-any.whl.metadata (11 kB)
# Collecting wget<4.0,>=3.2 (from pysus)
#   Downloading wget-3.2.zip (10 kB)
#   Preparing metadata (setup.py) ... done
# Collecting urllib3<2,>=1.21.1 (from elasticsearch==7.16.2->elasticsearch[preprocessing]==7.16.2->pysus)
#   Downloading urllib3-1.26.20-py2.py3-none-any.whl.metadata (50 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.1/50.1 kB 3.8 MB/s eta 0:00:00
# Requirement already satisfied: certifi in /usr/local/lib/python3.11/dist-packages (from elasticsearch==7.16.2->elasticsearch[preprocessing]==7.16.2->pysus) (2025.4.26)
# WARNING: elasticsearch 7.16.2 does not provide the extra 'preprocessing'
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil==2.8.2->pysus) (1.17.0)
# Requirement already satisfied: pytz>=2024.2 in /usr/local/lib/python3.11/dist-packages (from dateparser<2.0.0,>=1.1.8->pysus) (2025.2)
# Requirement already satisfied: regex!=2019.02.19,!=2021.8.27,>=2015.06.24 in /usr/local/lib/python3.11/dist-packages (from dateparser<2.0.0,>=1.1.8->pysus) (2024.11.6)
# Requirement already satisfied: tzlocal>=0.2 in /usr/local/lib/python3.11/dist-packages (from dateparser<2.0.0,>=1.1.8->pysus) (5.3.1)
# Requirement already satisfied: cramjam>=2.3 in /usr/local/lib/python3.11/dist-packages (from fastparquet>=2023.10.1->pysus) (2.10.0)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from fastparquet>=2023.10.1->pysus) (2025.3.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from fastparquet>=2023.10.1->pysus) (24.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas<3.0.0,>=2.2.2->pysus) (2025.2)
# Requirement already satisfied: pyyaml>=6 in /usr/local/lib/python3.11/dist-packages (from pyreaddbc>=1.1.0->pysus) (6.0.2)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.11/dist-packages (from urwid<3.0.0,>=2.1.2->pysus) (0.2.13)
# Downloading pysus-0.15.0-py3-none-any.whl (1.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 55.5 MB/s eta 0:00:00
# Downloading cffi-1.15.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (462 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 462.6/462.6 kB 31.3 MB/s eta 0:00:00
# Downloading dbfread-2.0.7-py2.py3-none-any.whl (20 kB)
# Downloading elasticsearch-7.16.2-py2.py3-none-any.whl (385 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 385.7/385.7 kB 23.0 MB/s eta 0:00:00
# Downloading numpy-1.26.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.2/18.2 MB 63.7 MB/s eta 0:00:00
# Downloading pycparser-2.21-py2.py3-none-any.whl (118 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 118.7/118.7 kB 10.6 MB/s eta 0:00:00
# Downloading python_dateutil-2.8.2-py2.py3-none-any.whl (247 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 247.7/247.7 kB 20.8 MB/s eta 0:00:00
# Downloading tqdm-4.64.0-py2.py3-none-any.whl (78 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.4/78.4 kB 7.2 MB/s eta 0:00:00
# Downloading aioftp-0.21.4-py3-none-any.whl (37 kB)
# Downloading bigtree-0.12.5-py3-none-any.whl (63 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.5/63.5 kB 5.5 MB/s eta 0:00:00
# Downloading dateparser-1.2.1-py3-none-any.whl (295 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 295.7/295.7 kB 23.7 MB/s eta 0:00:00
# Downloading fastparquet-2024.11.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 59.2 MB/s eta 0:00:00
# Downloading loguru-0.6.0-py3-none-any.whl (58 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 5.0 MB/s eta 0:00:00
# Downloading Unidecode-1.4.0-py3-none-any.whl (235 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 235.8/235.8 kB 18.1 MB/s eta 0:00:00
# Downloading urwid-2.6.16-py3-none-any.whl (297 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 297.2/297.2 kB 23.0 MB/s eta 0:00:00
# Downloading urllib3-1.26.20-py2.py3-none-any.whl (144 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 144.2/144.2 kB 12.2 MB/s eta 0:00:00
# Building wheels for collected packages: pyreaddbc, wget
#   Building wheel for pyreaddbc (pyproject.toml) ... done
#   Created wheel for pyreaddbc: filename=pyreaddbc-1.2.0-cp311-cp311-manylinux_2_35_x86_64.whl size=89810 sha256=a869a2d9f8272375dc3950431d1714a13a4de232679aa8a3b6f31ecdadb881b9
#   Stored in directory: /root/.cache/pip/wheels/1c/24/ff/03c9d6c394a14bf0f14a18333ff9345e8ff1bc3c62b10b399e
#   Building wheel for wget (setup.py) ... done
#   Created wheel for wget: filename=wget-3.2-py3-none-any.whl size=9655 sha256=a10f35015f6bfdef3c8645cbb87860d4f44bb2bce6651d4a2910ae363dd02230
#   Stored in directory: /root/.cache/pip/wheels/40/b3/0f/a40dbd1c6861731779f62cc4babcb234387e11d697df70ee97
# Successfully built pyreaddbc wget
# Installing collected packages: wget, dbfread, urwid, urllib3, Unidecode, tqdm, python-dateutil, pycparser, numpy, loguru, bigtree, aioftp, elasticsearch, dateparser, cffi, pyreaddbc, fastparquet, pysus
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 2.4.0
#     Uninstalling urllib3-2.4.0:
#       Successfully uninstalled urllib3-2.4.0
#   Attempting uninstall: tqdm
#     Found existing installation: tqdm 4.67.1
#     Uninstalling tqdm-4.67.1:
#       Successfully uninstalled tqdm-4.67.1
#   Attempting uninstall: python-dateutil
#     Found existing installation: python-dateutil 2.9.0.post0
#     Uninstalling python-dateutil-2.9.0.post0:
#       Successfully uninstalled python-dateutil-2.9.0.post0
#   Attempting uninstall: pycparser
#     Found existing installation: pycparser 2.22
#     Uninstalling pycparser-2.22:
#       Successfully uninstalled pycparser-2.22
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.0.2
#     Uninstalling numpy-2.0.2:
#       Successfully uninstalled numpy-2.0.2
#   Attempting uninstall: cffi
#     Found existing installation: cffi 1.17.1
#     Uninstalling cffi-1.17.1:
#       Successfully uninstalled cffi-1.17.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# pygit2 1.18.0 requires cffi>=1.17.0, but you have cffi 1.15.1 which is incompatible.
# dataproc-spark-connect 0.7.5 requires tqdm>=4.67, but you have tqdm 4.64.0 which is incompatible.
# dopamine-rl 4.1.2 requires tqdm>=4.64.1, but you have tqdm 4.64.0 which is incompatible.
# thinc 8.3.6 requires numpy<3.0.0,>=2.0.0, but you have numpy 1.26.2 which is incompatible.
# Successfully installed Unidecode-1.4.0 aioftp-0.21.4 bigtree-0.12.5 cffi-1.15.1 dateparser-1.2.1 dbfread-2.0.7 elasticsearch-7.16.2 fastparquet-2024.11.0 loguru-0.6.0 numpy-1.26.2 pycparser-2.21 pyreaddbc-1.2.0 pysus-0.15.0 python-dateutil-2.8.2 tqdm-4.64.0 urllib3-1.26.20 urwid-2.6.16 wget-3.2

# %%
from pysus import SIM

# Carrega o módulo SIM
sim = SIM().load()

# Obtém os arquivos de 2023 para o estado de SP e grupo CID10
arquivos_2023 = sim.get_files("CID10", year=2023)

# Faz o download do arquivo (ou dos arquivos, se houver mais de um)
parquets = [arquivo.download() for arquivo in arquivos_2023]

# Lê os dados como DataFrame
import pandas as pd

dfs = [pq.to_dataframe() for pq in parquets]

# Junta todos os dataframes, caso haja mais de um
df_2023 = pd.concat(dfs, ignore_index=True)

# Exibe as 5 primeiras linhas
print(df_2023.head())
# Out:
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# <ipython-input-9-ff9c31a0e174> in <cell line: 0>()
#       2
#       3 # Carrega o módulo SIM
# ----> 4 sim = SIM().load()
#       5
#       6 # Obtém os arquivos de 2023 para o estado de SP e grupo CID10
#
# /usr/local/lib/python3.11/dist-packages/pysus/ftp/__init__.py in __init__(self)
#     468
#     469     def __init__(self) -> None:
# --> 470         self.ftp = FTP("ftp.datasus.gov.br")
#     471         self.__content__ = {}
#     472
#
# /usr/lib/python3.11/ftplib.py in __init__(self, host, user, passwd, acct, timeout, source_address, encoding)
#     119         self.timeout = timeout
#     120         if host:
# --> 121             self.connect(host)
#     122             if user:
#     123                 self.login(user, passwd, acct)
#
# /usr/lib/python3.11/ftplib.py in connect(self, host, port, timeout, source_address)
#     156             self.source_address = source_address
#     157         sys.audit("ftplib.connect", self, self.host, self.port)
# --> 158         self.sock = socket.create_connection((self.host, self.port), self.timeout,
#     159                                              source_address=self.source_address)
#     160         self.af = self.sock.family
#
# /usr/lib/python3.11/socket.py in create_connection(address, timeout, source_address, all_errors)
#     861         try:
#     862             if not all_errors:
# --> 863                 raise exceptions[0]
#     864             raise ExceptionGroup("create_connection failed", exceptions)
#     865         finally:
#
# /usr/lib/python3.11/socket.py in create_connection(address, timeout, source_address, all_errors)
#     846             if source_address:
#     847                 sock.bind(source_address)
# --> 848             sock.connect(sa)
#     849             # Break explicitly a reference cycle
#     850             exceptions.clear()
#
# TimeoutError: [Errno 110] Connection timed out

# %%
df_2023.head()
# Out:
#   ORIGEM TIPOBITO   DTOBITO HORAOBITO NATURAL CODMUNNATU    DTNASC IDADE  \
# 0      1        2  01012023     0610      812    120070   26011941   481
# 1      1        2  01012023     1305      813    130180   20081966   456
# 2      1        2  01012023     0020      812    120030   15061968   454
# 3      1        2  01012023     1430      812    120045   14111965   457
# 4      1        2  01012023     1040      812    120035   12021958   464
#
#    SEXO RACACOR  ... FONTES TPRESGINFO TPNIVELINV NUDIASINF DTCADINF  \
# 0     1       4  ...
# 1     2       4  ...
# 2     2       1  ...
# 3     1       4  ...
# 4     2       4  ...
#
#    MORTEPARTO DTCONCASO FONTESINF ALTCAUSA  CONTADOR
# 0                                           2067
# 1                                           2146
# 2                                           2196
# 3                                           2839
# 4                                           3066
#
# [5 rows x 87 columns]

# %%
df_2023.columns
# Out:
# Index(['ORIGEM', 'TIPOBITO', 'DTOBITO', 'HORAOBITO', 'NATURAL', 'CODMUNNATU',
#        'DTNASC', 'IDADE', 'SEXO', 'RACACOR', 'ESTCIV', 'ESC', 'ESC2010',
#        'SERIESCFAL', 'OCUP', 'CODMUNRES', 'LOCOCOR', 'CODESTAB', 'ESTABDESCR',
#        'CODMUNOCOR', 'IDADEMAE', 'ESCMAE', 'ESCMAE2010', 'SERIESCMAE',
#        'OCUPMAE', 'QTDFILVIVO', 'QTDFILMORT', 'GRAVIDEZ', 'SEMAGESTAC',
#        'GESTACAO', 'PARTO', 'OBITOPARTO', 'PESO', 'TPMORTEOCO', 'OBITOGRAV',
#        'OBITOPUERP', 'ASSISTMED', 'EXAME', 'CIRURGIA', 'NECROPSIA', 'LINHAA',
#        'LINHAB', 'LINHAC', 'LINHAD', 'LINHAII', 'CAUSABAS', 'CB_PRE',
#        'COMUNSVOIM', 'DTATESTADO', 'CIRCOBITO', 'ACIDTRAB', 'FONTE',
#        'NUMEROLOTE', 'TPPOS', 'DTINVESTIG', 'CAUSABAS_O', 'DTCADASTRO',
#        'ATESTANTE', 'STCODIFICA', 'CODIFICADO', 'VERSAOSIST', 'VERSAOSCB',
#        'FONTEINV', 'DTRECEBIM', 'ATESTADO', 'DTRECORIGA', 'CAUSAMAT',
#        'ESCMAEAGR1', 'ESCFALAGR1', 'STDOEPIDEM', 'STDONOVA', 'DIFDATA',
#        'NUDIASOBCO', 'NUDIASOBIN', 'DTCADINV', 'TPOBITOCOR', 'DTCONINV',
#        'FONTES', 'TPRESGINFO', 'TPNIVELINV', 'NUDIASINF', 'DTCADINF',
#        'MORTEPARTO', 'DTCONCASO', 'FONTESINF', 'ALTCAUSA', 'CONTADOR'],
#       dtype='object')

# %%
df_2023.shape
# Out:
# (2931220, 87)

# %%
df_2023['CIRCOBITO'].value_counts()
# Out:
# CIRCOBITO
#      2623426
# 1     137052
# 3      83226
# 9      44982
# 2      32518
# 4      10016
# Name: count, dtype: Int64

# %%
df_suicidio = df_2023[df_2023['CIRCOBITO'] == '2']

# %%
df_suicidio
# Out:
#         ORIGEM TIPOBITO   DTOBITO HORAOBITO NATURAL CODMUNNATU    DTNASC  \
# 24           1        2  02012023     1100      813    130260   25101981
# 39           1        2  04012023     1920      812    120020   27082003
# 137          1        2  14012023     1200      812    120040   25101980
# 166          1        2  17012023     0830      812    120060   15101961
# 192          1        2  20012023     0100      812    120040   21011996
# ...        ...      ...       ...       ...     ...        ...       ...
# 2931022      1        2  23122023     0900      821    211000   17111987
# 2931049      1        2  24122023     2100      829    290320   29051988
# 2931069      1        2  25122023     1410      841    411770   16051969
# 2931083      1        2  26122023               817    171750   13111981
# 2931084      1        2  26122023     0030      817    170100   23102001
#
#         IDADE  SEXO RACACOR  ... FONTES TPRESGINFO TPNIVELINV NUDIASINF  \
# 24        441     1       4  ...
# 39        419     1       4  ...
# 137       442     1       4  ...
# 166       461     2       4  ...
# 192       426     1       4  ...
# ...       ...   ...     ...  ...    ...        ...        ...       ...
# 2931022   436     2       2  ...                            M
# 2931049   435     1       1  ...
# 2931069   454     1       1  ...
# 2931083   442     1       4  ...
# 2931084   422     2       4  ...                            M
#
#         DTCADINF  MORTEPARTO DTCONCASO FONTESINF ALTCAUSA  CONTADOR
# 24                                                         7886
# 39                                                         13647
# 137                                                        53256
# 166                                                        64794
# 192                                                        75977
# ...          ...         ...       ...       ...      ...       ...
# 2931022                                                    1432214
# 2931049                                                    1435294
# 2931069                                                    1438454
# 2931083                                                    1442252
# 2931084                                                    1442253
#
# [32518 rows x 87 columns]

# %%
df_suicidio['ASSISTMED'].value_counts()
# Out:
# ASSISTMED
# 2    19990
#       5398
# 1     4840
# 9     2290
# Name: count, dtype: Int64
